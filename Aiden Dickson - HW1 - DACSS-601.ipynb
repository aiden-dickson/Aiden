# %% [markdown]
# This is an interactive notebook similar to interactive (Jupyter) notebooks you might have used in a CS course. Technically, this file is a python notebook - thus the suffix of .ipynb. However, this particular notebook is setup to run the R kernal, thus any executible code snippets are run in R (not python.)
#
# There are two ways to complete this homework - use the template to run on your personal computer or interactively through Google Colab.
#
#
# ---
#
#
# ####Template on Personal Computer
# A template is provided at the bottom of this notebook that can be cut
# and pasted in order to edit and run in R/RStudio on your personal computer. After you have edited the file to your satisfaction, simply cut and paste the syntax back into this file to submit.
#
#
# ---
#
#
# ####Interactive Colab Notebook
# Alternatively, you can do the whole assignment in Google Colab by following the steps below. *This notebook is a copy of the original homework template, so you can edit it without affecting anyone else's copy.*
#
# *   Load Needed Libraries
# *   Mount Google Drive (requires authentication)
# *   Run R commands interactively in designated code snippets

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # Load Needed Libraries
#
# Note that the library *colabr* is a custom package created for the DACSS program by Hans Quiogue '21.

# %%
# Install these packages if you haven't already
if (!require('colabr')) devtools::install_github('hansquiogue/colabr', force=TRUE)
if (!require('tidyverse')) install.packages('tidyverse')
# Out:
# Loading required package: colabr
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘colabr’”
# Downloading GitHub repo hansquiogue/colabr@HEAD
# R.methodsS3 (NA    -> 1.8.1 ) [CRAN]
# cpp11       (0.2.6 -> 0.2.7 ) [CRAN]
# vctrs       (0.3.6 -> 0.3.7 ) [CRAN]
# tinytex     (0.30  -> 0.31  ) [CRAN]
# processx    (3.5.0 -> 3.5.1 ) [CRAN]
# callr       (3.5.1 -> 3.6.0 ) [CRAN]
# R.oo        (NA    -> 1.24.0) [CRAN]
# gargle      (NA    -> 1.1.0 ) [CRAN]
# reprex      (1.0.0 -> 2.0.0 ) [CRAN]
# R.utils     (NA    -> 2.10.1) [CRAN]
# googledrive (NA    -> 1.0.1 ) [CRAN]
# reticulate  (NA    -> 1.18  ) [CRAN]
# Installing 12 packages: R.methodsS3, cpp11, vctrs, tinytex, processx, callr, R.oo, gargle, reprex, R.utils, googledrive, reticulate
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ✔  checking for file ‘/tmp/Rtmpf3pFP1/remotes3a5a3ee33c/hansquiogue-colabr-7950faa/DESCRIPTION’
# ─  preparing ‘colabr’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘colabr_0.1.6.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Load libraries
library(colabr)
library(tidyverse)

# %% [markdown]
# ## Mount Google Drive to access Shared Data Folder

# %% [markdown]
# First, you will need to identify the link for the drive file or folder you will be using. For this assignement, the link is included in the command already.
#
# When you run the command below, you will be given a URL and an empty box. Click the URL, authenticate tidyverse using the correct UMass google account, and then hit the copy button to copy the authorization code back into the empty box below.

# %%
# Mount and Authenticate Google Drive File or Folder
download_drive("https://drive.google.com/drive/folders/1-3ancWOBCMoZVs70OuuKMPwVKTZGohx2/view?usp=sharing")
# Out:
# Error in download_drive("https://drive.google.com/drive/folders/1-3ancWOBCMoZVs70OuuKMPwVKTZGohx2/view?usp=sharing"): could not find function "download_drive"
# Traceback:

# %% [markdown]
# ## Read in Data

# %% [markdown]
# What you need to do from here on out is dependent on the dataset you choose to work with! Here's an example of how to read in a file using "+" as a delimiter. *Replace the text below with the R syntax that will read in your chosen file.*

# %%
#edit this command to read your data
myData <- read.csv("/content/congressional_hearings.csv", sep = ",", header=T)

# %% [markdown]
# Let's unpack the code above a bit.
# I'm creating an object called myData
#
# *   I'm creating an object called **myData**
# *   I'm using the **read.delim()** function to read in data
# *   I'm specifying the name of the **"file"** that contains the data
# *   if the **"file"** isn't in my working directory, it will need a path
# *   for google colab files in our shared directory, use the path **"/content/file"**
# *   Variables are delimited in the file by "+", but often commas (",") or tabs ("\t") are used
# *  I'm specifying that there is a header included in the data that features the variable names

# %% [markdown]
# ## Inspect Data

# %% [markdown]
# Now, let's check the first few rows. I'll let you remember how to do that!

# %%
head(myData)
# Out:
#   id    source     CISYear Unpublished Chamber filter_House filter_Senate
# 1 39106 70-H241-6  1970    0           1       1            0
# 2 39490 70-J841-1  1970    0           3       0            0
# 3 39498 70-J841-9  1970    0           3       0            0
# 4 39499 70-J841-10 1970    0           3       0            0
# 5 39507 70-J841-19 1970    0           3       0            0
# 6 39508 70-J841-20 1970    0           3       0            0
#   filter_Joint CISCommittee Sequence ⋯ title
# 1 0            241          6        ⋯
# 2 1            841          1        ⋯
# 3 1            841          9        ⋯
# 4 1            841          10       ⋯
# 5 1            841          19       ⋯
# 6 1            841          20       ⋯
#   description
# 1 General economic problems in the US.
# 2 Federal economic policies curbing inflation and insuring full employment with stable price.
# 3 President's annual economic report to congress.
# 4 President's annual economic report to congress.
# 5 Current economic situation to develop constructive measures for improving it.
# 6 Current economic situation to develop constructive measures for improving it.
#   pap_majortopic pap_subtopic Change. majortopic subtopic ReferralBills
# 1 1              100          NA      1          100
# 2 1              100          NA      1          100
# 3 1              100          NA      1          100
# 4 1              100          NA      1          100
# 5 1              100          NA      1          100
# 6 1              100          NA      1          100
#   StartDate AdditionalDates
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# ## Template (Cut and Paste into R or RStudio)

# %%
 # HomeworkOneTemplate.r
# This tells us what this file does
#
# dr 7.31.2020

# Reminder: the # "comments" out a line of text; that is, if you precede a line with "#", 
# then R ignores that line

# =-=-=-=-=-=-=-=-=-=-=-=-
# front end material. 
# =-=-=-=-=-=-=-=-=-=-=-=-

library(tidyverse)

# =-=-=-=-=-=-=-=-=-=-=-=-
# Some quick code reminders 
# =-=-=-=-=-=-=-=-=-=-=-=-

# Here's an example of storing an object.
hello <- paste("Hello World!")

# Look over there -> 
# In the "Environment" window, you'll see that you've created an object that is 
# now stored in your workspace. 

# Now type hello. R "pastes" the line of text that says "Hello World!" as your output.

# Ok, with those reminders out of the way, let's get some data into R

